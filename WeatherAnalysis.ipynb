# %% [markdown]
# #### MongoDB Code Lab

# %%
# %env HOST=mongodb+srv://cluster0.ok8cvs1.mongodb.net/sample_restaurants
# %env USER=victournguyen
# %env PW= yDyBkHMaS247BCDe57RgwaNrSGwT
# Out:
# env: HOST=mongodb+srv://cluster0.ok8cvs1.mongodb.net/sample_restaurants
# env: USER=victournguyen
# env: PW=yDyBkHMaS247BCDe57RgwaNrSGwT

# %%
# !mongosh "mongodb+srv://cluster0.ok8cvs1.mongodb.net/sample_restaurants" -u victournguyen -p yDyBkHMaS247BCDe57RgwaNrSGwT --quiet
# Out:
#  Atlas atlas-11tqln-shard-0 [primary] sample_restaurants>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-11tqln-shard-0 [primary] sample_restaurants>

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT}
# Out:
#  Atlas atlas-11tqln-shard-0 [primary] sample_restaurants>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-11tqln-shard-0 [primary] sample_restaurants>

# %%
# !{CONNECT} --eval "show collections"
# Out:
#  neighborhoods
# restaurants

# %%
# !{CONNECT} --eval "db.restaurants.findOne()"
# Out:
#  {
#   _id: ObjectId("5eb3d668b31de5d588f4292d"),
#   address: {
#     building: '469',
#     coord: [ -73.961704, 40.662942 ],
#     street: 'Flatbush Avenue',
#     zipcode: '11225'
#   },
#   borough: 'Brooklyn',
#   cuisine: 'Hamburgers',
#   grades: [
#     { date: ISODate("2014-12-30T00:00:00.000Z"), grade: 'A', score: 8 },
#     {
#       date: ISODate("2014-07-01T00:00:00.000Z"),
#       grade: 'B',
#       score: 23
#     },
#     {
#       date: ISODate("2013-04-30T00:00:00.000Z"),
#       grade: 'A',
#       score: 12
#     },
#     {
#       date: ISODate("2012-05-08T00:00:00.000Z"),
#       grade: 'A',
#       score: 12
#     }
#   ],
#   name: "Wendy'S",
#   restaurant_id: '30112340'
# }

# %%
# !{CONNECT} -f /home/jupyter/project6/mongo_queries.js
# Out:
#  ****************************************************************
# 1) Number of documents in the restaurant collection
# 25359
# ****************************************************************
# 2) Find restaurants with name = Riviera Caterer, sort by cuisine
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292a"),
#     address: {
#       building: '2780',
#       coord: [
#         -73.98241999999999,
#         40.579505
#       ],
#       street: 'Stillwell Avenue',
#       zipcode: '11224'
#     },
#     cuisine: 'American',
#     name: 'Riviera Caterer'
#   }
# ]
# ****************************************************************
# 3) Number of restaurants named Riviera Caterer
# 1
# ****************************************************************
# 4) Find restaurants with borough = Brooklyn and cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f42931"),
#     address: {
#       building: '6409',
#       coord: [
#         -74.00528899999999,
#         40.628886
#       ],
#       street: '11 Avenue',
#       zipcode: '11219'
#     },
#     cuisine: 'American',
#     name: 'Regina Caterers'
#   }
# ]
# ****************************************************************
# 5) Find restaurants with address.zipcode = 11209
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f42962"),
#     address: {
#       building: '10004',
#       coord: [
#         -74.03400479999999,
#         40.6127077
#       ],
#       street: '4 Avenue',
#       zipcode: '11209'
#     },
#     cuisine: 'Italian',
#     name: 'Philadelhia Grille Express'
#   }
# ]
# ****************************************************************
# 6) Find restaurants with borough = Brooklyn or cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292d"),
#     address: {
#       building: '469',
#       coord: [
#         -73.961704,
#         40.662942
#       ],
#       street: 'Flatbush Avenue',
#       zipcode: '11225'
#     },
#     cuisine: 'Hamburgers',
#     name: "Wendy'S"
#   }
# ]
# ****************************************************************
# 7) Find restaurants with borough = Brooklyn and not cuisine = American
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f4292d"),
#     address: {
#       building: '469',
#       coord: [
#         -73.961704,
#         40.662942
#       ],
#       street: 'Flatbush Avenue',
#       zipcode: '11225'
#     },
#     cuisine: 'Hamburgers',
#     name: "Wendy'S"
#   }
# ]
# ****************************************************************
# 8) Find restaurants with an array element score = 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f43383"),
#     grades: [
#       {
#         date: ISODate("2014-10-31T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-05-16T00:00:00.000Z"),
#         grade: 'A',
#         score: 11
#       },
#       {
#         date: ISODate("2013-11-19T00:00:00.000Z"),
#         grade: 'A',
#         score: 5
#       },
#       {
#         date: ISODate("2013-03-25T00:00:00.000Z"),
#         grade: 'B',
#         score: 19
#       },
#       {
#         date: ISODate("2012-09-05T00:00:00.000Z"),
#         grade: 'B',
#         score: 26
#       },
#       {
#         date: ISODate("2012-04-10T00:00:00.000Z"),
#         grade: 'C',
#         score: 49
#       },
#       {
#         date: ISODate("2011-11-21T00:00:00.000Z"),
#         grade: 'C',
#         score: 80
#       }
#     ]
#   }
# ]
# ****************************************************************
# 9) Find restaurants with an array element score between 70 and 80
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f42bd0"),
#     grades: [
#       {
#         date: ISODate("2014-10-28T00:00:00.000Z"),
#         grade: 'A',
#         score: 9
#       },
#       {
#         date: ISODate("2014-04-10T00:00:00.000Z"),
#         grade: 'A',
#         score: 12
#       },
#       {
#         date: ISODate("2013-08-08T00:00:00.000Z"),
#         grade: 'C',
#         score: 58
#       },
#       {
#         date: ISODate("2013-02-14T00:00:00.000Z"),
#         grade: 'A',
#         score: 13
#       },
#       {
#         date: ISODate("2012-06-15T00:00:00.000Z"),
#         grade: 'C',
#         score: 71
#       }
#     ]
#   }
# ]
# ****************************************************************
# 10) Find pizza restaurants in Manhattan not Dominos
# [
#   {
#     _id: ObjectId("5eb3d668b31de5d588f432f5"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '10Th Avenue Pizza & Cafe'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f455d2"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f4548e"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d669b31de5d588f45557"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   },
#   {
#     _id: ObjectId("5eb3d668b31de5d588f44a56"),
#     borough: 'Manhattan',
#     cuisine: 'Pizza',
#     name: '2 Bros Pizza'
#   }
# ]
# ****************************************************************
# 11) Number of pizza restaurants in Manhattan not Domino's
# 321

# %% [markdown]
# #### Prompt 1: Find the restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza. Return their borough, cuisine, and name. Sort the resulting documents by name. Limit the number of results to 5.

# %%
# Out:
# /bin/bash: line 1: Domino's: command not found
# /bin/bash: line 1: {CONNECT}: command not found

# %% [markdown]
# #### Prompt 2: Find the number of restaurants whose borough = Manhattan, whose cuisine = Pizza, and whose name is NOT Domino'S Pizza.

# %% [markdown]
# # begin project 6 work

# %%
# %env HOST=mongodb+srv://cluster0.ok8cvs1.mongodb.net/sample_weatherdata
# %env USER=victournguyen
# %env PW= yDyBkHMaS247BCDe57RgwaNrSGwT
# Out:
# env: HOST=mongodb+srv://cluster0.ok8cvs1.mongodb.net/sample_weatherdata
# env: USER=victournguyen
# env: PW=yDyBkHMaS247BCDe57RgwaNrSGwT

# %%
CONNECT="/usr/bin/mongosh $HOST -u $USER -p $PW --quiet"

# %%
# !{CONNECT} -f /home/jupyter/project6/project6_queries.js
# Out:
#  ****************************************************************
# 1) Get call letters, quality control process, and air temperature from coldest 5 documents (by air temperature) with call letters PLAT and type of FM-13 (logical and, sort)
# [
#   {
#     _id: ObjectId("5553a999e4b02cf71511e401"),
#     callLetters: 'PLAT',
#     qualityControlProcess: 'V020',
#     type: 'FM-13',
#     airTemperature: {
#       value: 0.1,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120cf6"),
#     callLetters: 'PLAT',
#     qualityControlProcess: 'V020',
#     type: 'FM-13',
#     airTemperature: {
#       value: 0.3,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf7151209bd"),
#     callLetters: 'PLAT',
#     qualityControlProcess: 'V020',
#     type: 'FM-13',
#     airTemperature: {
#       value: 1,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf7151209b6"),
#     callLetters: 'PLAT',
#     qualityControlProcess: 'V020',
#     type: 'FM-13',
#     airTemperature: {
#       value: 1.4,
#       quality: '1'
#     }
#   },
#   {
#     _id: ObjectId("5553a99ae4b02cf715120918"),
#     callLetters: 'PLAT',
#     qualityControlProcess: 'V020',
#     type: 'FM-13',
#     airTemperature: {
#       value: 1.4,
#       quality: '1'
#     }
#   }
# ]
# ****************************************************************
# 2) Get ceiling height and sea surface temperature from coldest 3 sea surface temps with ceiling height <= 22000 or sea surface temperature >= 10 (logical or, range, embedded filter - 1 and 2 layers deep, sort)
# [
#   {
#     _id: ObjectId("5553a998e4b02cf7151190ca"),
#     skyCondition: {
#       ceilingHeight: {
#         value: 22000
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf7151190bf"),
#     skyCondition: {
#       ceilingHeight: {
#         value: 22000
#       }
#     }
#   },
#   {
#     _id: ObjectId("5553a998e4b02cf7151190bd"),
#     skyCondition: {
#       ceilingHeight: {
#         value: 750
#       }
#     }
#   }
# ]
# ****************************************************************
# 3) Get dew point and pressure for data with dew point <= 5 and pressure = 1005, sort by dew point ascending (logical and, range, sort)
# [
#   {
#     dewPoint: {
#       value: -1.6
#     },
#     pressure: {
#       value: 1005
#     }
#   },
#   {
#     dewPoint: {
#       value: -0.8
#     },
#     pressure: {
#       value: 1005
#     }
#   },
#   {
#     dewPoint: {
#       value: 4.4
#     },
#     pressure: {
#       value: 1005
#     }
#   },
#   {
#     dewPoint: {
#       value: 4.5
#     },
#     pressure: {
#       value: 1005
#     }
#   },
#   {
#     dewPoint: {
#       value: 4.5
#     },
#     pressure: {
#       value: 1005
#     }
#   }
# ]
# ****************************************************************
# 4) Get wind speed rate and wind direction angle for slowest 3 (by wind speed rate) data points out of the data points with wind speed rate >= 25 or wind direction angle = 260 (logical or, range, embedded - 2 layers, sort)
# [
#   {
#     wind: {
#       direction: {
#         angle: 260
#       },
#       speed: {
#         rate: 0.5
#       }
#     }
#   },
#   {
#     wind: {
#       direction: {
#         angle: 260
#       },
#       speed: {
#         rate: 1
#       }
#     }
#   },
#   {
#     wind: {
#       direction: {
#         angle: 260
#       },
#       speed: {
#         rate: 1
#       }
#     }
#   }
# ]
# ****************************************************************
# 5) Get discrepancy of estimated observation precipitation for data points where discrepancy of estimated observation precipitation is '5' (embedded - 1 layer)
# [
#   {
#     precipitationEstimatedObservation: {
#       discrepancy: '5'
#     }
#   }
# ]
# ****************************************************************
# 6) Get wind type and wind speed rate for 5 slowest winds (embedded - 1 and 2 layers, sort)
# [
#   {
#     wind: {
#       type: 'N',
#       speed: {
#         rate: 0.5
#       }
#     }
#   },
#   {
#     wind: {
#       type: 'N',
#       speed: {
#         rate: 0.5
#       }
#     }
#   },
#   {
#     wind: {
#       type: 'N',
#       speed: {
#         rate: 0.5
#       }
#     }
#   },
#   {
#     wind: {
#       type: 'N',
#       speed: {
#         rate: 0.5
#       }
#     }
#   },
#   {
#     wind: {
#       type: 'N',
#       speed: {
#         rate: 0.5
#       }
#     }
#   }
# ]
# ****************************************************************
# 7) find data within a rectangle and get the dewPoint (embedded - 1 layer, range)
# [
#   {
#     position: {
#       coordinates: [
#         0.3,
#         53.5
#       ]
#     },
#     dewPoint: {
#       value: 999.9
#     }
#   },
#   {
#     position: {
#       coordinates: [
#         0.4,
#         53.5
#       ]
#     },
#     dewPoint: {
#       value: 999.9
#     }
#   },
#   {
#     position: {
#       coordinates: [
#         0.5,
#         53.6
#       ]
#     },
#     dewPoint: {
#       value: 0.9
#     }
#   },
#   {
#     position: {
#       coordinates: [
#         0.2,
#         50.4
#       ]
#     },
#     dewPoint: {
#       value: 999.9
#     }
#   },
#   {
#     position: {
#       coordinates: [
#         0.4,
#         53
#       ]
#     },
#     dewPoint: {
#       value: 0.9
#     }
#   }
# ]
# ****************************************************************
# 8) Get section information for 3 data points that have GF1 in sections (element in array matches)
# [
#   {
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MW1'
#     ]
#   },
#   {
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1'
#     ]
#   },
#   {
#     sections: [
#       'AG1',
#       'AY1',
#       'GF1',
#       'MD1',
#       'MW1',
#       'SA1',
#       'UA1'
#     ]
#   }
# ]
# ****************************************************************
# 9) Get the past weather observation manual and atmospheric pressure change tendency code for data points with past weather observation manual containing past atmospheric condition of value 1 and quality 1 and past weather period of 6 with quality 1 (embedded object in array matches)
# [
#   {
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '1',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     atmosphericPressureChange: {
#       tendency: {
#         code: '4'
#       }
#     }
#   },
#   {
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '1',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     atmosphericPressureChange: {
#       tendency: {
#         code: '8'
#       }
#     }
#   },
#   {
#     pastWeatherObservationManual: [
#       {
#         atmosphericCondition: {
#           value: '1',
#           quality: '1'
#         },
#         period: {
#           value: 6,
#           quality: '1'
#         }
#       }
#     ],
#     atmosphericPressureChange: {
#       tendency: {
#         code: '2'
#       }
#     }
#   }
# ]
# ****************************************************************
# 10) Get the coordinates, call letters, and elevation of data points with either the x or y or both being 69 (element in array matches)
# [
#   {
#     position: {
#       coordinates: [
#         5.2,
#         69
#       ]
#     },
#     elevation: 9999,
#     callLetters: 'UJFX'
#   },
#   {
#     position: {
#       coordinates: [
#         3.3,
#         69
#       ]
#     },
#     elevation: 9999,
#     callLetters: 'UJFO'
#   }
# ]

# %% [markdown]
# # begin extra credit work

# %%
# !{CONNECT} -f /home/jupyter/project6/exam1_extra_credit.js
# Out:
#  ****************************************************************
# 1) Insert a data point into the weather data
# {
#   acknowledged: true,
#   insertedId: 'AimanVictor100'
# }
# ****************************************************************
# 2) Insert a multiple data points into the weather data
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': 'AimanVictor2',
#     '1': 'AimanVictor3'
#   }
# }
# ****************************************************************
# 3) Insert a multiple data points into the weather data
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': 'AimanVictor20',
#     '1': 'AimanVictor30'
#   }
# }
# ****************************************************************
# 4) Update the position of data point AimanVictor20 to be (6, 3)
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 5) Update with push - add section UG2 to data point 5553a999e4b02cf71511bad6
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 6) Update the position of all data points with id containing 'AimanVictor' to (0, 0)
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 5,
#   modifiedCount: 5,
#   upsertedCount: 0
# }
# ****************************************************************
# 7) Update the elevation of all data points with call letters UJFX to 9998
# {
#   acknowledged: true,
#   insertedId: null,
#   matchedCount: 1,
#   modifiedCount: 1,
#   upsertedCount: 0
# }
# ****************************************************************
# 8) Delete data point AimanVictor20
# {
#   acknowledged: true,
#   deletedCount: 1
# }
# ****************************************************************
# 9) Delete any data points with sky condition ceiling height of 420
# {
#   acknowledged: true,
#   deletedCount: 25
# }
# ****************************************************************
# 10) Delete any data points that are not of type FM-13
# {
#   acknowledged: true,
#   deletedCount: 4
# }
